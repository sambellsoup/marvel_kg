# %%
import pandas as pd

# %%
marveldf = pd.read_csv('marvel.csv', engine='python')

# %%
marveldf
# Out:
#                 name                     alias                citizenship  \
# 0      Anthony Stark  ['Mark One', 'Iron Man']  ['American', 'Bulgarian']
# 1           T'Challa             Black Panther                   Wakandan
# 2       Dane Whitman              Black Knight                   American
# 3   Natalia Romanova               Black Widow                    Russian
# 4      Steven Rogers           Captain America                   American
# ..               ...                       ...                        ...
# 62            Nebula                       NaN                        NaN
# 63      Frank Castle                 The Rider                   American
# 64    Benjamin Grimm                 The Thing                   American
# 65   Eugene Thompson          Agent Anti-Venom                   American
# 66      Adam Warlock                   Warlock                        NaN
#
#    biological_mother  biological_father  \
# ...
